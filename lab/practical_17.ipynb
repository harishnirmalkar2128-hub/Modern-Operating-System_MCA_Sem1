# %%
# Deadlock Prevention: Hold and Wait

def request_resources(process, resources):
    print(f"{process} is requesting all resources at once...")
    print("Resources allocated:", resources)
    print("Process completed successfully.\n")

request_resources("Process P1", ["R1", "R2"])
request_resources("Process P2", ["R1", "R2"])
# Out:
# Process P1 is requesting all resources at once...
# Resources allocated: ['R1', 'R2']
# Process completed successfully.
#
# Process P2 is requesting all resources at once...
# Resources allocated: ['R1', 'R2']
# Process completed successfully.
