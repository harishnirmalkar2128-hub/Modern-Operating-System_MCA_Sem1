# %%
import platform

print("Operating System Information")
# Display OS name
print("Operating System Name:", platform.system())

# Display OS version
print("Operating System Version:", platform.version())

# Display architecture (32-bit / 64-bit)
print("Architecture:", platform.architecture()[0])
# Out:
# Operating System Information
# Operating System Name: Windows
# Operating System Version: 10.0.26200
# Architecture: 64bit
