# %%
import psutil

# Get network I/O statistics
net_stats = psutil.net_io_counters()

print(f"Bytes Sent: {net_stats.bytes_sent}")
print(f"Bytes Received: {net_stats.bytes_recv}")
# Out:
# Bytes Sent: 33546759
# Bytes Received: 37203529
