# %%
# Virtual File System Simulation

class VirtualFileSystem:
    def __init__(self):
        self.files = {}   # Dictionary to store files

    def create_file(self, filename):
        if filename in self.files:
            print("File already exists")
        else:
            self.files[filename] = ""
            print("File created:", filename)

    def write_file(self, filename, data):
        if filename in self.files:
            self.files[filename] = data
            print("Data written to file")
        else:
            print("File not found")

    def read_file(self, filename):
        if filename in self.files:
            print("File content:", self.files[filename])
        else:
            print("File not found")

    def list_files(self):
        print("Files in VFS:")
        for file in self.files:
            print(file)


# Main Program
vfs = VirtualFileSystem()

vfs.create_file("test.txt")
vfs.write_file("test.txt", "Hello Virtual File System")
vfs.read_file("test.txt")
vfs.list_files()
# Out:
# File created: test.txt
# Data written to file
# File content: Hello Virtual File System
# Files in VFS:
# test.txt
